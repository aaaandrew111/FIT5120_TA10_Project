# %% [markdown]
# ## Cleansing

# %%
import pandas as pd
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./fake reviews dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40432 entries, 0 to 40431
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  40432 non-null  object
#  1   rating    40432 non-null  float64
#  2   label     40432 non-null  object
#  3   text_     40432 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 1.2+ MB

# %%
df.head()
# Out:
#              category  rating label  \
# 0  Home_and_Kitchen_5     5.0    CG
# 1  Home_and_Kitchen_5     5.0    CG
# 2  Home_and_Kitchen_5     5.0    CG
# 3  Home_and_Kitchen_5     1.0    CG
# 4  Home_and_Kitchen_5     5.0    CG
#
#                                                text_
# 0  Love this!  Well made, sturdy, and very comfor...
# 1  love it, a great upgrade from the original.  I...
# 2  This pillow saved my back. I love the look and...
# 3  Missing information on how to use it, but it i...
# 4  Very nice set. Good quality. We have had the s...

# %%
from langdetect import detect, detect_langs

# %%
df.dropna(inplace=True)

# %%
df = df[df['text_'].apply(lambda x: len(x.split(' ')) >= 10)]
df = df[df['text_'].apply(lambda x: len(x.split(' ')) <= 30)]

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#        index                      category  rating label  \
# 0          0            Home_and_Kitchen_5     5.0    CG
# 1          1            Home_and_Kitchen_5     5.0    CG
# 2          2            Home_and_Kitchen_5     5.0    CG
# 3          3            Home_and_Kitchen_5     1.0    CG
# 4          4            Home_and_Kitchen_5     5.0    CG
# ...      ...                           ...     ...   ...
# 16225  38882  Clothing_Shoes_and_Jewelry_5     2.0    CG
# 16226  38917  Clothing_Shoes_and_Jewelry_5     5.0    CG
# 16227  38941  Clothing_Shoes_and_Jewelry_5     5.0    CG
# 16228  38997  Clothing_Shoes_and_Jewelry_5     2.0    CG
# 16229  39952  Clothing_Shoes_and_Jewelry_5     1.0    CG
#
#                                                    text_
# 0      Love this!  Well made, sturdy, and very comfor...
# 1      love it, a great upgrade from the original.  I...
# 2      This pillow saved my back. I love the look and...
# 3      Missing information on how to use it, but it i...
# 4      Very nice set. Good quality. We have had the s...
# ...                                                  ...
# 16225  I sent them back. They were too small and too ...
# 16226  These are my 5th pair,wear them everyday and t...
# 16227  Cute, comfy, as expected. These are a little w...
# 16228  Too short. I'm 6'1 and it fits me fine. I've h...
# 16229  <div id="video-block-R2BOE0VZD5O8GP" class="a-...
#
# [16230 rows x 5 columns]

# %%
idx_lst = []

for row in df.iterrows():
    idx = row[0]
    val = row[1]
    
    try:
        for element in detect_langs(val['text_']):
            if element.lang == 'en' and element.prob >= 0.6:
                idx_lst.append(idx)
            else:
                continue
    except:
        print(idx)
# Out:
# 15644

# %%
df.iloc[idx_lst, :].head()
# Out:
#    index            category  rating label  \
# 0      0  Home_and_Kitchen_5     5.0    CG
# 1      1  Home_and_Kitchen_5     5.0    CG
# 2      2  Home_and_Kitchen_5     5.0    CG
# 3      3  Home_and_Kitchen_5     1.0    CG
# 4      4  Home_and_Kitchen_5     5.0    CG
#
#                                                text_
# 0  Love this!  Well made, sturdy, and very comfor...
# 1  love it, a great upgrade from the original.  I...
# 2  This pillow saved my back. I love the look and...
# 3  Missing information on how to use it, but it i...
# 4  Very nice set. Good quality. We have had the s...

# %%
df = df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

# %%
df = df.sample(frac=1)

# %%
df = df[['category', 'rating', 'label', 'text_']]

# %% [markdown]
# ## Exploration

# %%
df['rating'] = df['rating'].astype('float')

# %%
df.describe()
# Out:
#              rating
# count  16230.000000
# mean       4.367714
# std        1.091294
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
n = len(df)
dict_ = df.rating.value_counts().to_dict()
for k in dict_:
    dict_[k] = dict_[k] / n
dict(sorted(dict_.items(), reverse=True))
# Out:
# {5.0: 0.6651879235982748,
#  4.0: 0.1713493530499076,
#  3.0: 0.07714109673444239,
#  2.0: 0.038632162661737524,
#  1.0: 0.04768946395563771}

# %%
df.category.value_counts()
# Out:
# Clothing_Shoes_and_Jewelry_5    1898
# Home_and_Kitchen_5              1802
# Pet_Supplies_5                  1730
# Sports_and_Outdoors_5           1707
# Toys_and_Games_5                1693
# Tools_and_Home_Improvement_5    1604
# Electronics_5                   1533
# Books_5                         1468
# Movies_and_TV_5                 1446
# Kindle_Store_5                  1349
# Name: category, dtype: int64

# %%
df.label.value_counts()
# Out:
# CG    8856
# OR    7374
# Name: label, dtype: int64

# %%
df.groupby(['category', 'label']).count()
# Out:
#                                     rating  text_
# category                     label
# Books_5                      CG        799    799
#                              OR        669    669
# Clothing_Shoes_and_Jewelry_5 CG       1026   1026
#                              OR        872    872
# Electronics_5                CG        849    849
#                              OR        684    684
# Home_and_Kitchen_5           CG        977    977
#                              OR        825    825
# Kindle_Store_5               CG        754    754
#                              OR        595    595
# Movies_and_TV_5              CG        791    791
#                              OR        655    655
# Pet_Supplies_5               CG        936    936
#                              OR        794    794
# Sports_and_Outdoors_5        CG        933    933
#                              OR        774    774
# Tools_and_Home_Improvement_5 CG        873    873
#                              OR        731    731
# Toys_and_Games_5             CG        918    918
#                              OR        775    775

# %%
df['text_'] = df['text_'].astype('str')

# %%
df.rating.plot.hist(bins=5)

# %% [markdown]
# ## Database Import data

# %%
df[df['text_'].apply(lambda x: len(x.split(' ')) == 30)]['text_'].values[1]
# Out:
# 'I was cutting some 2" thick plywood and using a saw blade for the saw blade, and I had to cut through the plywood to get the saw blade to'

# %%
df = df[df['text_'].apply(lambda x: x[-1] == '.')]

# %%
df1 = df.head(200)

# %%
df1.to_csv('./fake_review_200.csv', index=None)

# %% [markdown]
# ## Visual

# %%
import nltk
import re
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer 
from nltk.tokenize import RegexpTokenizer

stopwords = stopwords.words('english')
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'\w+')
# As this dataset is fetched from twitter so it has lots of people tag in tweets
# we will remove them 
tags = r"@\w*"


def preprocess_text(sentence, stem = False):
    
    sentence = [re.sub(tags, "", sentence)]
    text = []
    for word in sentence:
        
        if word not in stopwords:
            
            if stem:
                text.append(stemmer.stem(word).lower())
            else:
                text.append(word.lower())
    return tokenizer.tokenize(" ".join(text))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tinkpad\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#preprocess_text(df.text_[11])
df.text_ = df.text_.map(preprocess_text)
df.head()
# Out:
#                            category  rating label  \
# 15684  Clothing_Shoes_and_Jewelry_5     4.0    OR
# 375              Home_and_Kitchen_5     5.0    OR
# 5522                Movies_and_TV_5     5.0    OR
# 7863   Tools_and_Home_Improvement_5     4.0    CG
# 8528                 Pet_Supplies_5     4.0    OR
#
#                                                    text_
# 15684  [my, danske, clogs, are, a, 41, and, loose, fi...
# 375    [nice, size, fits, perfectly, love, the, added...
# 5522   [i, absolutely, love, the, twilight, zone, the...
# 7863   [the, light, could, be, brighter, but, it, s, ...
# 8528   [my, pups, loved, this, but, they, were, able,...

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
df['stemmed'] = df['text_'].apply(lambda x: [stemmer.stem(y) for y in x]) # Stem every word.
#df = df.drop(columns=['unstemmed'])
df.head()
# Out:
#                            category  rating label  \
# 15684  Clothing_Shoes_and_Jewelry_5     4.0    OR
# 375              Home_and_Kitchen_5     5.0    OR
# 5522                Movies_and_TV_5     5.0    OR
# 7863   Tools_and_Home_Improvement_5     4.0    CG
# 8528                 Pet_Supplies_5     4.0    OR
#
#                                                    text_  \
# 15684  [my, danske, clogs, are, a, 41, and, loose, fi...
# 375    [nice, size, fits, perfectly, love, the, added...
# 5522   [i, absolutely, love, the, twilight, zone, the...
# 7863   [the, light, could, be, brighter, but, it, s, ...
# 8528   [my, pups, loved, this, but, they, were, able,...
#
#                                                  stemmed
# 15684  [my, dansk, clog, are, a, 41, and, loos, fit, ...
# 375    [nice, size, fit, perfect, love, the, ad, orga...
# 5522   [i, absolut, love, the, twilight, zone, the, p...
# 7863   [the, light, could, be, brighter, but, it, s, ...
# 8528   [my, pup, love, this, but, they, were, abl, to...

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
text = df.text_

# %%
text_lst = []
for k in text:
    for w in k:
        text_lst.append(w)

# %%
text = ' '.join(text_lst)

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
text = df[(df['label'] == 'OR') & (df['category'] == 'Movies_and_TV_5')].text_

text_lst = []
for k in text:
    for w in k:
        text_lst.append(w)
        
text = ' '.join(text_lst)

wordcloud = WordCloud(max_font_size=50, max_words=20, background_color="white").generate(text)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
text = df[(df['label'] == 'CG') & (df['category'] == 'Movies_and_TV_5')].text_

text_lst = []
for k in text:
    for w in k:
        text_lst.append(w)
        
text = ' '.join(text_lst)

wordcloud = WordCloud(max_font_size=50, max_words=20).generate(text)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
df1[(df1['label'] == 'CG') & (df1['category'] == 'Movies_and_TV_5')]['text_'].values
# Out:
# array([list(['good', 'show', 'did', 'not', 'find', 'it', 'entertaining', 'not', 'for', 'children', 'would', 'not', 'recommend']),
#        list(['great', 'movie', 'my', 'wife', 'and', 'i', 'love', 'the', 'movie', 'very', 'good', 'movie']),
#        list(['always', 'been', 'a', 'barbra', 'fan', 'and', 'this', 'movie', 'was', 'very', 'funny', 'i', 'also', 'enjoyed', 'the', 'music', 'and', 'the', 'story']),
#        list(['it', 'was', 'pretty', 'good', 'not', 'a', 'bad', 'movie', 'just', 'not', 'a', 'lot', 'of', 'action']),
#        list(['i', 'bought', 'this', 'dvd', 'to', 'see', 'what', 'the', 'movie', 'was', 'like', 'i', 'didn', 't', 'know', 'what', 'the', 'movie', 'was', 'about']),
#        list(['information', 'humor', 'a', 'little', 'slow', 'at', 'times', 'but', 'good', 'enough', 'to', 'make', 'a', 'movie', 'worth', 'watching', 'i', 'really', 'enjoyed', 'the', 'film', 'the', 'script', 'and', 'acting', 'were', 'very', 'good']),
#        list(['this', 'movie', 'is', 'one', 'of', 'the', 'most', 'entertaining', 'movies', 'i', 've', 'seen', 'in', 'a', 'long', 'time']),
#        list(['good', 'movie', 'i', 'did', 'not', 'find', 'it', 'entertaining', 'not', 'for', 'children']),
#        list(['if', 'you', 're', 'a', 'fan', 'of', 'the', 'old', 'toho', 'movies', 'you', 'will', 'like', 'this', 'one', 'i', 'was', 'just', 'blown', 'away', 'by', 'the', 'way', 'the', 'movie', 'moves']),
#        list(['this', 'movie', 'kept', 'and', 'children', 's', 'books', 'the', 'movie', 'was', 'funny', 'and', 'it', 'kept', 'my', 'attention', 'very', 'good']),
#        list(['this', 'is', 'a', 'replacement', 'dvd', 'for', 'the', 'original', 'the', 'two', 'movies', 'are', 'also', 'identical', 'in', 'their', 'appearance'])],
#       dtype=object)
